# %%
from os import path
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch


# Set Matplotlib Parameters
plt.style.use('bmh')
plt.rc('text', usetex=True)   #  Might require installing TeX fonts
plt.rc('axes', facecolor='w', labelcolor='b', edgecolor='k', labelsize=20)
plt.rcParams['font.size'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18

# %%
plt.figure(figsize=(6, 5))
plt.grid(False, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

plt.plot([1, 2, 3, 4], [41.3, 43.4, 43.7, 43.9], color='#1f77b4', linewidth=2.0, label='Original', marker='o' )

plt.xticks([1, 2, 3, 4])
# plt.xlim(0,4)
# plt.minorticks_off()


plt.xlabel('Averaging Last $N$ Checkpoints', color="grey", weight='black')
plt.ylabel('MATH Validation Accuracy (in \%)', color="grey", weight='black')

# plt.title('Impact of Incorrect Pairing on MATH Validation Accuracy', color="grey", 
#           fontsize=22, fontweight='extra bold')
        #   , fontname='DejaVu Sans')


plt.tight_layout(pad=0.07)
plt.savefig("../plots/ckpt_avging.jpg", format='jpg', dpi=300)
plt.savefig("../plots/ckpt_avging.pdf", format='pdf', dpi=300)
plt.show()
# Out:
# /var/folders/gq/j0mm4vs16k7ftsbyhlr0sl8c0000gp/T/ipykernel_37086/2086431786.py:2: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   plt.grid(False, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
